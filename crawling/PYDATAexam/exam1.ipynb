# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)
# Out:
# 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HPE\Documents\machine_learning_basic\PYDATAexam

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   pydatavenv    C:\Users\HPE\AppData\Roaming\jupyter\kernels\pydatavenv
#   python3       C:\ProgramData\Anaconda3\envs\pydatavenv\share\jupyter\kernels\python3

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 4E57-393C
#
#  C:\Users\HPE\Documents\machine_learning_basic\PYDATAexam 디렉터리
#
# 2022-01-11  오후 02:20    <DIR>          .
# 2022-01-11  오후 02:20    <DIR>          ..
# 2022-01-11  오후 02:20    <DIR>          .ipynb_checkpoints
# 2022-01-11  오전 11:16    <DIR>          chromedriver_win32
# 2022-01-11  오후 02:18            25,968 exam1.ipynb
# 2022-01-11  오전 10:37               955 first.ipynb
# 2022-01-11  오후 02:20    <DIR>          output
# 2022-01-11  오전 10:58             1,553 second.ipynb
#                3개 파일              28,476 바이트
#                5개 디렉터리  334,845,566,976 바이트 남음

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Tue, 11 Jan 2022 05:21:24 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=c5c884e3ba06a3957dbf8a6656561ba920032aaeb7b62cee18e67322ab073abb; Expires=Wed, 12 Jan 2022 05:21:24 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x0000025A1CB02A60>
# [ header 정보 ]----------
# ('Date', 'Tue, 11 Jan 2022 05:20:53 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
url = 'https://www.naver.com/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'http://www.yes24.com/Main/default.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.naver.com/  페이지의 인코딩 정보 : utf-8
#
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m
# ===========================================================
# http://www.yes24.com/Main/default.aspx  페이지의 인코딩 정보 : ks_c_5601-1987
#
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>Y
# ===========================================================

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ URL 문자열 정보 추출 1 ]
# 타입정보 :  <class 'urllib.parse.ParseResult'>
# 도메인정보 :  movie.daum.net
# 패스정보 :  /moviedb/main
# 쿼리정보 :  movieId=93252
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :
# URL 문자열정보 :  https://movie.daum.net/moviedb/main?movieId=93252
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='movie.daum.net', path='/moviedb/main', params='', query='movieId=93252', fragment='')
#
# [ URL 문자열 정보 추출 2 ]
# 도메인정보 :  docs.python.org
# 패스정보 :  /3/library/urllib.parse.html
# 쿼리정보 :
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :  urlparse-result-object
# URL 문자열정보 :  https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='docs.python.org', path='/3/library/urllib.parse.html', params='', query='', fragment='urlparse-result-object')
#
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x0000025A1CB15340>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
# head는 정보만 받아오는 형식
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Tue, 11 Jan 2022 05:20:54 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '164', 'Connection': 'close', 'Content-Type': 'text/html'}
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Tue, 11 Jan 2022 05:20:54 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Connection': 'close', 'Content-Type': 'text/html'}
# 응답된 콘텐츠가 없어요

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
    r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
# 텍스트로 가져올 땐 인코딩을 하고 갖고 오고, 컨텐츠로 가져오려는 경우 디코딩하여 갖고 온다.
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("c:/Temp/test.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
print("[ find_all()의 text=True 매개변수 ]")
print(bs.find_all("li", text=True))  # 콘텐츠가 텍스트로만 구성된
# Out:
# [ string 속성 ]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [ text 속성 ]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [ contents 속성 ]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']
# [ find_all()의 text=True 매개변수 ]
# [<li>테스트2</li>, <li>테스트3</li>]

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    #content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 돈 룩 업
# 평점 : 9
# 리뷰글 : 흔한 재난영화가 아닌 현시대상을 반영하는 블랙코미디라 더 뜻하는게 많네요. 재밌게 봤어요 특히 디카프리오 연기랑 제니퍼로렌스 연기 좋았어요. 티모시까지 나오네요
# -----------------------------------------
# 영화 제목 : 해바라기
# 평점 : 10
# 리뷰글 : 그냥 최고의 명작임ㅋㅋㅋ
# -----------------------------------------
# 영화 제목 : 킹스맨: 퍼스트 에이전트
# 평점 : 10
# 리뷰글 : 간만에 재미있게 봤습니다.
# -----------------------------------------
# 영화 제목 : 남한산성
# 평점 : 10
# 리뷰글 : 좋은 작품입니다.누군가의 추천으로 봤는데,배우들의 연기가 정말 좋네요!
# -----------------------------------------
# 영화 제목 : 외출
# 평점 : 10
# 리뷰글 : 한줄영화평: 우리... 사랑일까요?한줄 감상평: 24살의 손예진을 보다.
# -----------------------------------------
# 영화 제목 : 돈 룩 업
# 평점 : 10
# 리뷰글 : 사랑, 자비, 겸손, 충정의 시대는 저물고 오직 나만 좋으면 정의라고 떠들어대는 개구리 세상의 도래. 그리고 그 끝
# -----------------------------------------
# 영화 제목 : 불한당: 나쁜 놈들의 세상
# 평점 : 8
# 리뷰글 : 꽤 볼만함. 전혜진의 어설픈 연기력빼곤..  볼때마다 연기력 최악.
# -----------------------------------------
# 영화 제목 : 제인 에어
# 평점 : 10
# 리뷰글 : 책이던 영화던 제인에게 더 넓은 세상을 알려주고 싶었다.. 영화 자체는 원작을 잘 살렸다고 생각함
# -----------------------------------------
# 영화 제목 : 그 시절, 우리가 좋아했던 소녀
# 평점 : 10
# 리뷰글 : 구라가 아니라 3일에 한번씩은 보는듯
# -----------------------------------------
# 영화 제목 : 석양의 갱들
# 평점 : 9
# 리뷰글 : 서부영화는 총질이 나와야 제 맛이라고만 생각했는데...나이가 드니 진짜 명작입니다...
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 9,돈 룩 업,흔한 재난영화가 아닌 현시대상을 반영하는 블랙코미디라 더 뜻하는게 많네요. 재밌게 봤어요 특히 디카프리오 연기랑 제니퍼로렌스 연기 좋았어요. 티모시까지 나오네요
# 10,해바라기,그냥 최고의 명작임ㅋㅋㅋ
# 10,킹스맨: 퍼스트 에이전트,간만에 재미있게 봤습니다.
# 10,남한산성,좋은 작품입니다.누군가의 추천으로 봤는데,배우들의 연기가 정말 좋네요!
# 10,외출,한줄영화평: 우리... 사랑일까요?한줄 감상평: 24살의 손예진을 보다.
# 10,돈 룩 업,사랑, 자비, 겸손, 충정의 시대는 저물고 오직 나만 좋으면 정의라고 떠들어대는 개구리 세상의 도래. 그리고 그 끝
# 8,불한당: 나쁜 놈들의 세상,꽤 볼만함. 전혜진의 어설픈 연기력빼곤..  볼때마다 연기력 최악.
# 10,제인 에어,책이던 영화던 제인에게 더 넓은 세상을 알려주고 싶었다.. 영화 자체는 원작을 잘 살렸다고 생각함
# 10,그 시절, 우리가 좋아했던 소녀,구라가 아니라 3일에 한번씩은 보는듯
# 9,석양의 갱들,서부영화는 총질이 나와야 제 맛이라고만 생각했는데...나이가 드니 진짜 명작입니다...
# -----------------------------------------------------
# 10,스파이더맨: 노 웨이 홈,덕후들을 감동에 휩싸이게 만드는 스토리
# 1,연애 빠진 로맨스,연출이며 연기며 개연성까지 총체적 난국임 이게 네이버평점 8을 넘는다는게 참
# 10,씽2게더,1편도 너무 재미있게 봤는데 1편을 능하가는 속편이에요 진짜! 아직 상반기의 반도 지나지 않았지만, 제 기준 상반기 최고의 작품이 될 것같아요!!
# 10,씽2게더,이번 시리즈는 전작보다 영상이며 사운드에 엄청 힘을 준게 느껴지고 스토리도 전개가 빨라서 지루하지 않고 재밌습니다.
# 10,우리는 모두 어른이 될 수 없었다,영화에 굉장히 몰입 됩니다 Ost가 저를 잡아먹는 기분 좋아요 !
# 10,듄,드니 블뇌브 감독의 영화를 봐왔던 사람이라면 추천!! 개인적으로 호흡은 느리지만 배경과 음악이 압도적이다. 기대만큼 좋았음.
# 6,원샷,재미있게 잘 봤습니다.
# 10,스파이더맨: 노 웨이 홈,앞에 살짝 지루할때쯤 재밌어짐 눈 못뗌
# 4,여고괴담 여섯번째 이야기 : 모교,뭔내용인지 약간 어려움
# 9,스파이더맨: 노 웨이 홈,팬들의 가슴을 뭉클하게 하는 순간!
# -----------------------------------------------------
# 5,아내와 제자들:네토라레,여주 목소리가 굉장히 차분하네
# 1,트웬티 해커,전개도 별로, 연기는 더 별로.
# 10,기억의 시간,
# 6,친구부부,에로에 너무 많은걸 바라지 말자
# 10,씽2게더,아직 안 봤는데 기대하ㅏ고 있을게요^~^
# 5,야수,배우들 연기는 잘 하는데 왜 그렇게 소리만 지르게 시키셨어요. ㅠ.ㅠ 개연성 떨어지고 사이다 스러움도 거의 없고. 만드는대로 보는게 관객들 할 일이지만 끝까지 보기 힘들었네요. ㅠ.ㅠ 많이 아쉽습니다.
# 10,씽2게더,최고의 영화! N차 관람하러 왔어요!
# 10,비밀은 없다,나도 모르게 빠져들다가 마침내 나오는 탄식.
# 7,킬러의 보디가드 무삭제 특별판,볼거 없을땐 한번 더 보는것도
# 10,원샷,연출로 까진 않겠음 진짜 편집점 끝내주게 자연스럽고 재밌게 봄
# -----------------------------------------------------
# 9,원샷,총격액션만으로도 충분히 재밌고 볼만함
# 6,스파이더맨: 노 웨이 홈,미드 플래시 모티브를 그냥 따왔네 보는내내 플래시랑 겹쳐서 집중도 떨어짐
# 7,램,제일 초반에 양들이 카메라를 바라보는게 너무 인상적이었다.제작사 때문에 공포 영화인가 했는데 공포는 아니었음.
# 10,더 포가튼 배틀,지난 수 십...년 동안 봐왔던 수 백편의 전쟁 영화 중에 단연코 원탑이다. 전쟁은 결코 군인들만의 문제는 아니야...
# 10,경관의 피,믿고 보는 조진웅  경찰연기도 잘어울리는 최우식
# 1,경관의 피,진짜 개노잼입니다. 개지루해
# 7,해피 뉴 이어,볼 건 배우들밖에 없음 연출 그냥 연말에 따뜻한 감성 느끼기에만 좋은 영화 연출은 정말 별로임..
# 10,스파이더맨: 노 웨이 홈,스파이더맨들끼리 유대하는 장면들이 넘 힐링됌 ㅎ
# 8,드라이브 마이 카,가장 가까운, 가장 사랑하는 사람의 마음 조차 완벽히 이해할 수 없음에서 오는 두려움, 그것과 마주하지 못한 남자가 치르는 마음의 형벌.
# 10,경관의 피,올해 영화관 가서 관람한 첫 영화인데 추천하고 싶네여
# -----------------------------------------------------
# 7,트롤,무난하게 재밌슴
# 9,스파이더맨: 노 웨이 홈,재밌게 잘봤네요 예전 스파이더맨 생각 납니다.
# 9,더 포가튼 배틀,전투씬 거의 없고 드라마에 가깝지만 주인공 3명의 갈등이나 심리 변화 같은 것을 섬세하게 잘 표현해서 지루하지 않고 몰입감이 높고 볼 만합니다.
# 6,트롤: 월드 투어,다괜찮은데 남캐 전작과 더빙 목소리 다른게 좀 신경쓰임
# 8,해피뻐스데이,차마 돌을 던질 수 가 없다. 이건 피해자들의 이야기거든.
# 8,양들의 침묵,한번 보는걸로는 내용이 너무 어려운느낌! 많은 의미를 담고있는 영화인것같고 다보고난뒤에 해석을 찾아보고나서야 영화의 내용을이해할 수 있었음
# 9,스파이더맨: 노 웨이 홈,관객들이 원하는 것을 다 보여주지만 스토리 개연성이나 액션 면에서 다소 아쉽다..하지만 꿈에서나 나올법한 조합은 인정!
# 2,돈 룩 업,드럽게 재미없네 ㅎㅎ별로다 ㅈㄴ심 지루함
# 10,마녀,제발 2편 내주세요!! 귀공자 꼭 살려서 같이 나오구!!! 진심 마녀를 몇번을 보며 존버하고 있는지 몰라 ㅠㅠ
# 8,스파이더맨: 노 웨이 홈,어떤 이가 영화 소감으로 "스파이더맨의 삶" 이라고 적었었던데, 그 말에 100% 공감합니다. 지금까지 그러하듯이 단순히 악당과 싸우는게 아니라 피터파크와 스파이더맨이라는 하나의 존재로서 다루는 것이 차별성이었다고 생각합니다. 추천합니다.
# -----------------------------------------------------
# 10,스파이더맨: 노 웨이 홈,ㅋㅋ개잼있넥ㅋㅋㅋㅋ
# 10,명탐정 코난: 비색의 탄환,이번화 주인공은 역시 아카이네 가족이네
# 10,씽2게더,씽 1 너무 재밌었어서 기대 했는데 기대를 충족합니다.
# 8,조제, 호랑이 그리고 물고기들,원작 실사 영화가 있는지도 모르고 감상하였지만 감명 깊게 봤다. 평소 장애인들은 일상생활 속에서 어떠한 감정과 생각을 갖고 지낼지에 대해 깊고 자세히 생각해 보지는 못하였는데, 두 남녀의 다양한 관점에서의 이야기를 풀어내는 과정에서 여러 상황들을 잘 연출해 주었기에 비장애인의 시선으로 장애인의 삶을 볼 때와 장애인의 시선으로 비장애인의 삶을 보는 두 가지 관점 모두를 잘 느낄 수 있어서 좋았다.
# 9,돈 룩 업,웃기지만 웃기지만은 않은 이야기
# 6,경관의 피,진짜 기대해서 봤는데 맨처음 박희순님 대사 발음뭉게져서 무슨말인지 모르겠어서 몰입감 다떨어졌고 액션도 시원한맛도없고 내용도 솔직히모르겠다
# 1,경관의 피,별로였어요 추천하지는 않습니다..
# 6,소울,목적 달성을 위해 인생을 전투적으로 살 필요는 없다.하지만 목적없는 삶은 매우 무기력하고 우울하다.내가 삶에 잡혀 먹히는 느낌이고 하루하루 루틴이 없어 중독에 빠져 나올 수가 없다.이게 다 목적이 없어서다.이 목적은 거창한 꿈을 얘기하는 것이 아니라 내가 해야 될 일들을 달성 하면서 매일 매일 나 자신을 만들어 나가는 것이다.단순히 성공을 얘기 하는 것이 아닌 내 삶의 질의 순환을 얘기하는 것이다. 개인적으로 전혀 공감이 안 갔다.
# 10,노웨어 스페셜,주인공은 울지 않았는데 보는 나만 계속 울었다.
# 10,완벽한 타인,실력파배우들의 연기 잘봤고. 결론은 태수 게이임
# -----------------------------------------------------
# 10,꾼,연기력때문에 몰입도 최고네요!
# 10,스파이더맨: 노 웨이 홈,세명의 스파이더맨
# 10,스파이더맨: 노 웨이 홈,지금까지 이런 영화는 없었다
# 10,코코,나를 울리다니 제법이야..
# 8,이스케이프 룸,킬링타임용으론 괜춘합니다
# 6,우주 전쟁,스필버그 톰크루즈 조합이라 믿고봤는데 킬링타임용 그이상도 그이하도 아님 저 무지막지한 외계인을 어떻게 물리칠지 그 기대감으로 끝까지 봤지만 돌아오는건 허무와 배신감 ㅋ 결국 가족의 소중함을 일깨운다는 미국식 억지감성이 너무나 유치하다
# 2,경관의 피,재미없음 후회합니다 결말이 이상함
# 4,스파이더맨: 노 웨이 홈,어벤져스 때 잘 싸웠던 스파이더맨이 고블린 하나 때문에 쩔쩔 매는 점과 다른 세계의 스파이더맨을 억지로 껴맞추려 하다 보니 개연성이 매우 떨어짐. 그리고 억지스럽게 감동을 주려는 점도 몰입도 저하에 일조함. 왜 평점이 9점인지 이해가 안감. 마블 중에 워스트에 꼽힐듯
# 10,드라이브 마이 카,긴 러닝타임만큼 긴 여운이 남는
# 1,여곡성,내 발이 연기 더 잘할듯.
# 4,경관의 피,ㄹㅇ 재미없다 최우식 나와서 기생충이며 흥행한 영화나 드라마 잘 골라서 이번 영화도 기대하고 봤는데 감동도 재미도 없고 지루함뿐
# 10,경관의 피,생각보다 너무 좋았어요 ?
# 10,프라미싱 영 우먼,결말이 슬프긴한데.. 현실은 피해자가 죽어서도 이정도의 복수도 못하는 걸.. 오히려 그런 점을 노렸을지도
# 10,어벤져스: 엔드게임,디즈니+에서 수십번 봤어요 and I am lron man크~ 기가막힙니다
# 10,어벤져스: 엔드게임,디즈니+에서 수십번 봤어요 and I am lron man크~ 기가막힙니다
# -----------------------------------------------------
# 8,스파이더맨: 노 웨이 홈,이 때 까지 본 마블 영화 중에 제일 재미있었다
# 10,씽2게더,모든 장면이 예술이었다.
# 10,그래비티,이런 설정으로 영화를 만들 수 있구나 감탄한 영화
# 10,아이,아이를 보며 많은 생각이 들었다
# 10,킹스맨: 퍼스트 에이전트,킹스맨 팬이라면 누구나 만족할만한 연출. 라스푸틴의 광기어린 액션씬이 기억에 남네요. 허구와 실제 역사를 적절히 버무린 스토리.
# 10,고스트버스터즈 라이즈,아 눈물난다 ㅠㅠ 최고
# 9,해탄적일천,사랑에 맹목적이던 젊음의 바다를 뒤로하고 참 오래 걸어왔다. 아직도 걸어가고 있다.
# 10,마스크,
# 6,경관의 피,다소 아쉬운 영화 좋은 배우들이라서 몰입감은 좋았음  뻔한 내용인데 어려운 풀이 방식이 난해했음
# 10,노웨어 스페셜,굿
# -----------------------------------------------------
# 10,라스트 나잇 인 소호,굿
# 2,스파이더맨: 노 웨이 홈,동창회도 아니고 액션도 별로고스파이더맨을 뭔 애송이로 만들더니이상하게 지들이 끝맺는거 같다스토리도 억지다  일을 굳이 만들어서 껴놓은 느낌
# 10,아멜리에,굿
# 4,라붐,엄마와 아빠의 맞바람 주인공은 남친때문에 울고불고 난리쳐놓고 막판엔 다른남자애와 눈맞아서 헬렐레...
# 10,연애 빠진 로맨스,굿
# 10,유체이탈자,굿
# 10,엔칸토: 마법의 세계,굿
# 8,엔칸토: 마법의 세계,너무 기대를 했나.. 영상미는 좋은데 스토리는 조금 밋밋하네요 ㅠㅠ 갑자기 끝난 느낌
# 10,램,굿
# 10,스파이더맨: 노 웨이 홈,토비 다시 볼수 있어서 너무너무 좋았어요...ㅠㅠ 스토리 너무 좋아요 ㅠㅠ
# -----------------------------------------------------
# 2,해피 뉴 이어,이게 영화야...? 진심?
# 7,어메이징 스파이더맨 2,시계탑 연출은 언제봐도 지렸다.
# 1,세렌디피티,바람장려영화임??? 좋은영화래서봤다가짜증나네 둘다애인있으면서왜저럼 ㅡㅡ 남의결혼식장들어가서 스탑 하는건무슨경웈ㅋㅋㅋㅋ
# 1,스파이더맨: 노 웨이 홈,최악의 연개성, 도대체 무슨 생각으로 이 영화만들엇지? 그냥 스파이더맨 골수팬들 눈요깃거리하라고 개연성 억지로 맞춤
# 10,드라이브 마이 카,생각이 많아지는 영화
# 9,만추,늦은 가을에, 잠시 머무르다 이내 사라지는 갈빛의 사랑
# 10,고스트버스터즈 라이즈,굿
# 10,매트릭스: 리저렉션,굿
# 10,드라이브 마이 카,굿
# 10,해피 뉴 이어,굿
# -----------------------------------------------------
# 10,킹스맨: 퍼스트 에이전트,굿
# 10,스파이더맨: 노 웨이 홈,굿
# 10,씽2게더,굿
# 8,경관의 피,조진웅 배우님과 최우식 배우님의 조합은 영화를 안 볼 수 없더라구요^^ 영화도 재미있고 연기도 잘하셔서 재미있게 본 영화지만 중간중간 대사가 잘 안들린다는 감상평은 인정입니다. 배우님들의 발음과 발성의 문제가 아닌 음향의 문제인 듯 싶습니다..! 이 부분 제외하면 정말 재미있게 잘 봤습니다! 조진웅 배우님 최우식 배우님 살앙해욥..!
# 10,경관의 피,굿
# 6,경관의 피,아직도 이런 영화가 나오는구나
# 10,피부를 판 남자,굿
# 5,스파이더맨: 노 웨이 홈,계속 감성팔이만하고 개재미없음.
# 10,씽2게더,소름이돋고 온몸에 전율이울렸다 정말 또 듣고픈 노래!
# 10,지옥의 묵시록,월남전의 광기 이 영화에서 인간다움이란 찾아볼수 없다. 롤링 스톤즈의 paint it black과 가장 어울리는 영화
# -----------------------------------------------------
# 9,해탄적일천,오래된 영화지만 생각해 볼만한 부분이 많았음
# 10,어벤져스: 엔드게임,가장 완벽한 엔딩이었다고 생각함
# 6,고장난 론,기대 안하고 봤는데 왜이렇게 귀엽나요
# 10,노웨어 스페셜,영화를 보는 내내 한켠에 서서 그들과 함께 기억상자를 차곡차곡 채워간 것 같은 느낌을 받았다. 어떤 작별은 새로운 시작이 된다는걸 느꼈고 사랑하는 사람을 위해 내가 남길 수 있는 건 무엇 일지 생각해보게됐다. 덤덤하지만 여운과 감동은 전혀 잔잔하지 않은 영화였다ㅠㅠ아가배우 너무 사랑스럽고 아버지역 배우분 눈만봐도 울컥한다ㅠ
# 10,스파이더맨: 노 웨이 홈,꿀잼꿀잼 너무 재미있다
# 10,씽2게더,정말 재미있었다. ㅋㅋ
# 10,플래툰,월남전 영화중 최고가 아닌 역대 전쟁영화중 최고봉 플래툰을 능가하는 전쟁영화는 없다.
# 10,씽2게더,
# 10,해피 뉴 이어,
# 10,디어 헌터,잊을수없는 강렬한 원샷 윌켄의 최고의 연기 지옥의 묵시록, 플래툰과는 다른 가장 현실적인 반전 메시지를 던진다.
# -----------------------------------------------------
# 10,돈 룩 업,20년 전엔 아마겟돈이 혜성을 폭발 시켰다면20년 후인 지금은 혜성에 돈룩업 당했다.
# 10,씽2게더,1편보다 나은 2편이번엔 춤과 노래가 완전체를 이룬다.
# 6,경관의 피,박희순배우 원래 옹알스임 이 배우 콘텐츠는 무족권 자막틀고 ㅜ
# 10,고스트버스터즈 라이즈,고스트버스터스를 어려서 봤던 70-80년대생들에게는 선물같은 영화입니다.OST나 오마주 장면들 모두 감동이네요.
# 10,하울의 움직이는 성,아름다운 마음 용감한 소피가 하울의 벽을 허물다 아름다운 이상향
# 10,차일드 인 타임,영국영화 원래 좀 이랬는데 요즘엔 잘 모르는 사람들도 많은듯 취향에 안맞을 수는 있겠지만 잘 만든 영화라고 생각한다 끝에 여운이 남는다
# 10,기적,이영화를 영화관에서 안보길 잘했네요..보는 내내 눈물이 계속 나서 영화관에서 봤음 챙피할뻔했네요~~^^;~요새 지친일상에 정말 단비처럼 사람의 순수함을 느끼게 해주는 영화였습니다..배우님들 연기최고였구요...아름다운 영화네요...최고에요...
# 10,원더,너무감동적이에요최고!!
# 10,레이디스 나잇,
# 10,인생은 아름다워,인생영화입니다 강추합니다
# -----------------------------------------------------
# 5,해피 뉴 이어,설득력 없는 각본.곽재용의 심플하지 못한 연출.단점이 많지만 한지민.윤아의 후덜덜 미모와 윤하의<느린 우체통>은 확실한 장점.
# 10,원샷,진짜... 밀리터리 영화 꽤 많이 봤는데 진짜 원테이크 액션도 장난 아니고 속도감도 있어서 지루하지 않았다
# 10,기적,너무 감동적이고 참 따뜻한 영화보는내내 흐뭇한 미소가 떠나질 않았다.배우들 연기도 굿굿봐도 후회안할 영화! 꼭 보시길?
# 6,경관의 피,음?솔직히 좀 난잡한 느낌이네요. 그리고 진짜 우리나라 영화는 대사할 때 제발 배경음 좀 줄여서 더빙해주세요 .진짜 대사가 배경음이 시끄러워서 안 들리면 엄청 짜증나거든요
# 10,킹스맨: 퍼스트 에이전트,진짜 이렇게 재밌는영화 처음봅니다... 눈물나는 포인트도 있고.. 전쟁씬도 많고 한번 더보고싶어요
# 2,해피 뉴 이어,
# 8,노웨어 스페셜,
# 10,씽2게더,영화관에서 안 보면 바보
# 9,씽2게더,Ost 쩐다....설마 1편보다 재미있겠어? 이랬는데 "응 1편보다 재미있네"
# 7,씽2게더,역시 동물 캐릭터들의 매력은 여전하고 전체적인 뮤직 넘버도 좋다. 눈을 즐겁게 하는 스케일은 더 커졌다. 다만, 캐릭터들의 이야기가 좀 많이 분산되고, 전작과 같이 감동을 크게 주는 한방의 뮤직이 없어 아쉬움이 남는다.
# -----------------------------------------------------
# 10,씽2게더,너무 재밌었다. 오랜만에 1편 등장했던 애들도 보고, 중간에 탄이들도 반가웠당 막타에 가서 끝까지 보고 싶었는데 직원들이 재촉함..ㅠㅜ 다시 보러 가고 싶다
# 10,엔칸토: 마법의 세계,연년생 애기들과 4가족이 메가박스에서 한 번 보고 네이버 시리즈온 내려와서 한 번 더 봤는데 이제 거의 매일매일 매주 주말 보는 영화로 바뀌었습니다 ㅎ 볼 때마다 몰랐던 부분 놓쳤던 부분들,영화 제작의 디테일을 볼수록 알게 되어서 좋았습니다! OST는 다 들을수록 좋네요~ 그리고 포옹과 함께 화해의 메세지는 가정에서 그리고 인간관계에서 가장 중요한 것이 무엇인지 알려주는 가족이 함께 앉아서 보기에 정말 좋은 가슴 따뜻한 디즈니 영화 볼수록 더 강추드립니다~~^^
# 8,고장난 론,재미있었으나 무시무시한 미래가 느껴지기도 했음. 이런 애니, 영화가 더 나왔으면 함. ai시대의 윤리성을 다룬…
# 10,씽2게더,극장에서 신나게 즐긴건 오랜만인것 같아요.영화 중간중간 노래 구성이 너무 잘되어있어 재밌게 봤습니다.
# 10,해리 포터와 혼혈 왕자,아니 왜 이렇게 평점 낮은거지...?스토리가 제일 좋은데...
# 10,플라이트 93,RIP RIP RIP RIP RIP RIP
# 5,늑대소년,할매한테 아부떠는 솜씨가.. 늑대가 아니라 애완견.
# 10,스파이더맨: 노 웨이 홈,연기는 말 할 것도 없고 최곱니다 ㅠㅠ
# 10,귀신소리 찾기,공포영화 많이보는데 제일 싫은게 스토리 빈약하면서 소리로 놀래키기만 하는 영화들... 이 영화를 좀 참고하시길
# 10,경관의 피,개인적으로  개꿀잼이엇늠
# 1,여타짜,이거볼시간에 AV를 보겠다영화가 완전3류영화보다 못하냐
# -----------------------------------------------------
# 1,스파이더맨: 노 웨이 홈,재미없어서 한시간도안돼서나옴미취학적이고 악역들은 말안듣는초딩같아서 짜증나서 나옴. 개인적으로 본영화중에 최악이었다. 열심히 번돈에 돈버렸다고생각했다.
# 1,차이니즈 조디악 특별판,성용나온다 해서 보았는데(집에서) 재미도 별로 내용도 그렇고..그리고 권상우를 자신의 목소리가 아닌 지네나라 사람 목소리로 바꾸어놓고하여튼 ㅉ OO들..쯪쯪
# 10,언브로큰,주인공분의 연기도 너무 완벽했던 것 같아요ㅠㅠ보는 내내 계속 마음도 아프고 한 편으로는 일본군이 참 잠혹하단 생각이 계속 들었어요 뿐만아니라 도대체 어디까지가 최악일까도 생각하게 만든 영화였어요 진심으로 전세계 사람들 모두가 한번 쯤 꼭 이 영화를 한번 쯤 보셨으면 좋겠습니다
# 10,스파이더맨: 노 웨이 홈,오랜시간이 지나서 만난 얼굴들이 반가웠습니다.
# 10,씽2게더,와~엄청난 상상력~ 천재네요~
# 9,어벤져스: 엔드게임,마블 10년 동안 사랑했습니다. 그리고 앞으로 10년도 잘 부탁합니다
# 10,핵소 고지,첨엔 양심적 병역거부를 진지하게 다루다가 갑자기, 호러, 카오스로 변한다. 그런상황에서도 흔들리지않고 신념을 지키기란 힘들것이다. 만약에 내눈앞에서 아내가 강간당하고있고, 난 묶여있지만 옆에 총을집어서 쏠수있는 상황이라면, 집총거부를위해 보구만있을것인가. 혼돈에 빠질것이다. 그런데 전쟁묘사가 호러적인데, 정말 저러한가? 아님 과장된것인가?
# 9,어벤져스: 인피니티 워,어벤져스4를 위한 훌륭한 가교
# 10,씽2게더,웃기고 귀엽고 감동적이고다하는 영화ㅠㅠ 넘 적절한 ost또보고싶어여
# 10,원초적 본능,"인류 최고의 명작."
# -----------------------------------------------------
# 10,씽2게더,너무재밌었어요 8세딸과 잘봤네요
# 10,돈 룩 업,이런 의미심장한 영화를 보면서도 대부분은  겉핡기만 이해할것이란것이 참으로 이영화내용과 일치하지않는가? 간간이 주는 먹이나 먹고 보여주는것만 보고살아라! 라고 사회지배층들은 그들의 스스로는 독립한 자아라고 생각하는 노예들에게 말한다
# 7,경관의 피,일본 소설이 원작이라 그런지 큰 임팩트는 없지만 그렇다고 잔잔하기만 하지 않는 적절한 레시피로 만든 영화. 워낙 배우진들이  출중한지라 큰 반전을 기대했지만 인간미를 포기하지 않은 영화. 원작이 있는 만큼 한편으로는 교훈이나 의미를 잔잔하게 선사한다.살다보면 원칙만으로 해결할수 없는 부분들이 많은데 법을 어기면서 까지 정의를 바로 세워야 할까 하는 일상의 의문이나 생각이 이영화를 보면서 다시금 생각해보는 계기가 되었다.또 한편으로는 조진웅이 맡은 반장처럼 법을 어기면서 오로지 양심적으로 정의를 실행하는 사람이 있을까..예를 들어 범죄자들에게 돈을 빌리고 갚는데 여러번하다보면 인간적으로 범인잡는데만 쓰지 않고 본인 주머니에도 꿀꺽할수 있고 돈의 맛이 들지 않을까 싶다. 또 어떻게 보면 집이나 차 옷들을 보면 수사를 위해서라는 것은 합리화이고 이미 권력과 자본의 맛을 본 세속적인 낭만주의로 보인다.마지막장면은 역시 피는 물보다 진하구나 하는 생각을 들게 하는 동시에 일본영화 같은 싱거운 마무리였다.
# 10,내안의 그놈,부담없이 볼수있는ㅋㅋ그런영화!잼나용~
# 10,틱, 틱... 붐!,조나단 라슨의 헌신과 열정은 헛되지 않았다.
# 9,경관의 피,내용이 너무 좋았고 주인공의 행동 모습이 깊이 와닿았습니다
# 2,사냥의 시간,이제훈 연기도 뭔가 좀 이상하고 그냥 개답답하다 멍청이새끼들 캐릭터만 모아놔서
# 8,돈 룩 업,인간의 오만은.. 멸망을 낳고
# 9,모가디슈,신기했던게 허준호 배우님은 연기 원래 잘하는거 알았지만 미쳤음.. 근데 조인성이 중간부터 내가 알던  발연기 조인성이 아니였음 너무 잘함 그리고 모든 배우들이 다 연기를 잘해서 좋았음
# 10,남자사용설명서,
# -----------------------------------------------------

# %%
print(reviews[0].contents)
# Out:
# ['\n', <a class="movie color_b" href="?st=mcode&amp;sword=200910&amp;target=after">산타킬러스</a>, '\n', <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:50%">별점 - 총 10점 중</span></span><em>5</em>
# </div>, '\n', <br/>, '크리스마스니까 보기 좋았던,, \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t', <a class="report" href="#" onclick="report('mais****', 'ubmcE2fFZF75uPtxaMDqIL0o5POGYGHyLGL27SRB2K4=', '크리스마스니까 보기 좋았던,,', '17901431', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>, '\n']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
booklist = bs.select('a.gd_name')

for bookdom in booklist:
    title.append(bookdom.string)
    link.append(bookdom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '밑바닥부터 시작하는 딥러닝 ', 'Do it! 첫 파이썬', 'Do it! 점프 투 파이썬 + Do it! 첫 파이썬 ', '파이썬 알고리즘 인터뷰', '핸즈온 머신러닝', '파이썬 머신러닝 완벽 가이드', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', 'Do it! 점프 투 파이썬 + Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편 + Do it! 파이썬 생활 프로그래밍', '파이썬을 이용한 비트코인 자동매매', '파이썬 증권 데이터 분석 ', '모두의 인공지능 기초 수학', '혼자 공부하는 첫 프로그래밍 with 파이썬 ', '밑바닥부터 시작하는 딥러닝 2', '모두의 데이터 분석 with 파이썬', '모두의 알고리즘 with 파이썬', '프로그래머를 위한 수학 : 파이썬으로 하는 3D 그래픽스, 시뮬레이션, 머신러닝', '웹 크롤링 & 데이터 분석 with 파이썬', '한권으로 파이썬과 드론 날로 먹기 인공지능 편']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916', '/Product/Goods/74269975', '/Product/Goods/96024871', '/Product/Goods/91433923', '/Product/Goods/91437485', '/Product/Goods/91446225', '/Product/Goods/34970929', '/Product/Goods/89904189', '/Product/Goods/91446188', '/Product/Goods/91084402', '/Product/Goods/89959711', '/Product/Goods/87044746', '/Product/Goods/91219874', '/Product/Goods/91446242', '/Product/Goods/98135876', '/Product/Goods/90578506', '/Product/Goods/91358533', '/Product/Goods/90617738', '/Product/Goods/72173703', '/Product/Goods/72227684', '/Product/Goods/40443936', '/Product/Goods/106045879', '/Product/Goods/106175772', '/Product/Goods/106157392']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

# xml 형식
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser') # lxml

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')
# Out:
# {'서울': ['-11~0', '-11~0', '-5~4', '-5~4', '-3~1', '-3~1', '-8~0', '-8~0', '-6~0', '-6~0', '-6~-1', '-9~-1', '-6~2'], '인천': ['-9~-1', '-9~-1', '-3~3', '-3~3', '-3~0', '-3~0', '-7~-1', '-7~-1', '-5~0', '-5~0', '-5~-1', '-8~-2', '-5~2'], '수원': ['-11~1', '-11~1', '-6~4', '-6~4', '-3~1', '-3~1', '-8~1', '-8~1', '-7~2', '-7~2', '-7~0', '-9~-1', '-7~3'], '파주': ['-16~1', '-16~1', '-9~3', '-9~3', '-7~0', '-7
~2', '-5~4', '-5~4', '-5~2', '-7~1', '-6~4'], '군산': ['-8~2', '-8~2', '-5~5', '-5~5', '-1~3', '-1~3', '-6~2', '-6~2', '-6~4', '-6~4', '-5~2', '-6~1', '-6~4'], '정읍': ['-8~0', '-8~0', '-5~5', '-5~5', '0~3', '0~3', '-6~1', '-6~1', '-6~3', '-6~3', '-5~2', '-6~1', '-5~4'], '남원': ['-9~3', '-9~3', '-5~6', '-5~6', '-1~4', '-1~4', '-7~3', '-7~3', '-7~5', '-7~5', '-6~3', '-8~1', '-6~5'], '고창': ['-7~1', '-7~1', '-5~5', '-5~5', '0~4', '0~4', '-5~1', '-5~1', '-6~4', '-6~4', '-5~2', '-6~1', '-5~4'], '무주': ['-14~2', '-14~2', '-8~5', '-8~5', '-1~3', '-1~3', '-10~2', '-10~2', '-11~3', '-11~3', '-9~1', '-11~0', '-8~4'], '부산': ['-5~7', '-5~7', '1~9', '1~9', '3~9', '3~9', '-2~7', '-2~7', '0~9', '0~9', '0~7', '-3~6', '0~8'], '울산': ['-6~6', '-6~6', '-2~8', '-2~8', '0~9', '0~9', '-4~7', '-4~7', '-2~8', '-2~8', '-3~6', '-5~4', '-3~7'], '창원': ['-7~5', '-7~5', '-2~7', '-2~7', '0~8', '0~8', '-4~6', '-4~6', '-3~7', '-3~7', '-3~6', '-4~4', '-3~6'], '진주': ['-10~7', '-10~7', '-6~8', '-6~8', '-4~8', '-4~8', '-6~7', '-6~7', '-6~7', '-6~7', '-5~6', '-7~5', '-6~7'], '거창': ['-10~5', '-10~5', '-7~7', '-7~7', '-3~6', '-3~6', '-8~4', '-8~4', '-8~5', '-8~5', '-7~3', '-8~3', '-7~5'], '통영': ['-6~6', '-6~6', '-1~8', '-1~8', '2~8', '2~8', '-3~7', '-3~7', '-2~7', '-2~7', '-1~7', '-4~6', '-1~7'], '대구': ['-8~5', '-8~5', '-4~7', '-4~7', '-1~7', '-1~7', '-6~5', '-6~5', '-6~6', '-6~6', '-5~5', '-7~3', '-5~6'], '안동': ['-12~3', '-12~3', '-8~5', '-8~5', '-3~4', '-3~4', '-8~3', '-8~3', '-8~4', '-8~4', '-8~2', '-10~1', '-8~4'], '포항': ['-7~6', '-7~6', '-1~8', '-1~8', ...

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
print(data)
page = data.decode('utf-8', 'ignore')
print(page)
res_content = json.loads(data)

print(res_content["result"])
# Out:
# b'\xef\xbb\xbf{ "result" : "\xeb\xb8\x8c\xeb\x9d\xbc\xec\x9a\xb0\xec\xa0\x80 \xec\x9a\x94\xec\xb2\xad\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4." }'
# ﻿{ "result" : "브라우저 요청입니다." }
# 브라우저 요청입니다.
